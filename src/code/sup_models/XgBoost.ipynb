# %% [markdown]
# # XGBoost
#
# in this part we will use ensemble (boosting) model(XgBoost) to predict the repeating and  non repeating frbs

# %%
# importing the  necessary libraries 
import pandas as pd 
import numpy as np

# %%
# reading the csv file
df = pd.read_csv("../../datasets/cul_cat1.csv")
df.head()
# Out:
#    Unnamed: 0      tns_name    previous_name repeater_name      ra    dec  \
# 0           0  FRB20180725A  180725.J0613+67         -9999   93.42  67.07
# 1           1  FRB20180727A  180727.J1311+26         -9999  197.72  26.42
# 2           2  FRB20180729A  180729.J1316+55         -9999  199.40  55.58
# 3           3  FRB20180729B  180729.J0558+56         -9999   89.93  56.50
# 4           4  FRB20180730A  180730.J0353+87         -9999   57.39  87.19
#
#       gb  bonsai_dm  low_ft_68  up_ft_68  ...   fre_width  fre_width_ob  \
# 0  21.29      716.6        0.0       2.7  ...  450.875425         274.8
# 1  85.60      642.1        0.0       1.9  ...  645.927163         400.0
# 2  61.16      108.4        0.0       4.6  ...  293.157605         292.5
# 3  15.68      318.6        0.0       0.9  ...  414.871625         358.4
# 4  25.11      849.2        3.3       2.3  ...  647.063272         359.0
#
#    rest_width        energy   bright_temp  log_fre_width  log_redshift  \
# ...

# %%
# splittimg the data into training and testing sets 

from sklearn.model_selection import train_test_split
x = df[['bc_width','flux','fluence', 'dm_exc_ne2001','peak_freq','log_bright_temp','rest_width','log_fre_width','log_energy']]
y = df[['repeating']]
X_train , X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, stratify=y, random_state=42)

# %%
print(len(X_train) , len(X_test))
# Out:
# 415 179

# %%
# we standardize the input features by removing the mean and scaling the variance
# to unity. 

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform((X_train))

X_test = scaler.transform(X_test) #subsequently appling to the testing data

# %%
from imblearn.over_sampling import SMOTE
smt = SMOTE()
X_train,y_train = smt.fit_resample(X_train,y_train)

print(y_train.sum())
# Out:
# repeating    349
# dtype: int64

# %%
from xgboost import XGBClassifier
# params = {'objective': 'binary:logistic', 'base_score': 0.5, 'booster': 'gbtree', 'callbacks': None, 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 0, 'grow_policy': 'depthwise', 'importance_type': None, 'interaction_constraints': '', 'learning_rate': 0.3, 'max_bin': 256, 'max_cat_threshold': None, 'max_cat_to_onehot': 4, 'max_delta_step': 0, 'max_depth': 6, 'max_leaves': 0, 'min_child_weight': 1, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 100, 'n_jobs': None, 'num_parallel_tree': 1, 'random_state': None, 'reg_alpha': 0, 'reg_lambda': 1, 'sampling_method': 'uniform', 'scale_pos_weight': 1, 'subsample': 1, 'tree_method': 'exact', 'validate_parameters': None, 'verbosity': None, 'predictor' : 'auto', 'interaction_constraints': '', 'use_lable_encoder':False}
model5 = XGBClassifier(objective = 'binary:logistic',base_score= 0.5,booster= 'gbtree',colsample_bylevel= 1,colsample_bynode= 1,colsample_bytree= 1,early_stopping_rounds= None,eval_metric= None,gamma= 0,grow_policy= 'depthwise',importance_type= None,learning_rate= 0.3,max_bin= 256,max_cat_to_onehot= 4,max_delta_step= 0,max_depth= 6,max_leaves= 0,min_child_weight= 1,num_parallel_tree= 1,reg_alpha= 0,reg_lambda= 1,sampling_method= 'uniform',scale_pos_weight= 1,subsample= 1,tree_method= 'exact',)
model5.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               device=None, early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints=None, learning_rate=0.3, max_bin=256,
#               max_cat_threshold=None, max_cat_to_onehot=4, max_delta_step=0,
#               max_depth=6, max_leaves=0, min_child_weight=1, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=1, random_state=None, ...)

# %%
y_pred = model5.predict(X_test)

# %%
# calculating the f2 score for this model 

from sklearn.metrics import fbeta_score
f2 = fbeta_score(y_test, y_pred, beta=2, average='weighted')

print(f"F2 Score: {f2:.4f}")
# Out:
# F2 Score: 0.9330

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
cm = confusion_matrix(y_test,y_pred)

# %%
# Normalize confusion matrix values to percentages
cm_percent = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] * 100

# %%
import seaborn as sns

labels = np.array([["{0}\n{1:.2f}%".format(value, percent) for value, percent in zip(row, percent_row)] 
                   for row, percent_row in zip(cm, cm_percent)])
plt.figure(figsize=(6, 6))
sns.heatmap(cm, annot=labels, fmt='', cmap='viridis', cbar=True, annot_kws={"size": 16})

# Adding labels and title
plt.xlabel("Predicted label", fontsize=14)
plt.ylabel("True label", fontsize=14)

# Customize tick labels
plt.xticks([0.5, 1.5], ["Non-repeating", "Repeating"], fontsize=12)
plt.yticks([0.5, 1.5], ["Non-repeating", "Repeating"], fontsize=12)

# Show the plot
plt.show()
